# %%
import sys

sys.path.append("../../../..")

# %%
from neural_networks.ai.log_analysis import load_logs_by_model

# %%
results = load_logs_by_model("LSTM")
results = results[results["run_name"] == "LSTM na poprawnych danych"]

# %%
results.sort_values(["test_accuracy"], ascending=False)
# Out:
#    model      run_id  run_counter                   run_name  \
# 31  LSTM  1731161731           10  LSTM na poprawnych danych
# 37  LSTM  1731161731            2  LSTM na poprawnych danych
# 30  LSTM  1731161731            1  LSTM na poprawnych danych
# 42  LSTM  1731161731            7  LSTM na poprawnych danych
# 41  LSTM  1731161731            6  LSTM na poprawnych danych
# 40  LSTM  1731161731            5  LSTM na poprawnych danych
# 43  LSTM  1731161731            8  LSTM na poprawnych danych
# 44  LSTM  1731161731            9  LSTM na poprawnych danych
# 36  LSTM  1731161731           15  LSTM na poprawnych danych
# 39  LSTM  1731161731            4  LSTM na poprawnych danych
# 33  LSTM  1731161731           12  LSTM na poprawnych danych
# 35  LSTM  1731161731           14  LSTM na poprawnych danych
# 32  LSTM  1731161731           11  LSTM na poprawnych danych
# 34  LSTM  1731161731           13  LSTM na poprawnych danych
# 38  LSTM  1731161731            3  LSTM na poprawnych danych
#
#                     timestamp   test_loss  test_accuracy   tmax  \
# 31 2024-11-09 15:39:39.532161    0.599977       0.653484  1.000
# 37 2024-11-09 15:20:55.096526    0.616408       0.645283  1.997
# 30 2024-11-09 15:18:12.677695    0.676475       0.634652  1.000
# 42 2024-11-09 15:33:52.674994    0.635349       0.587571  1.000
# 41 2024-11-09 15:32:15.470062    0.629567       0.581921  1.000
# 40 2024-11-09 15:30:40.335156    0.670081       0.580038  1.000
# 43 2024-11-09 15:35:48.202607    0.676877       0.566855  1.000
# 44 2024-11-09 15:37:53.550443    0.679453       0.553672  1.000
# 36 2024-11-09 15:48:23.521773  158.927750       0.521657  1.000
# 39 2024-11-09 15:29:34.243240    0.692914       0.519774  1.000
# 33 2024-11-09 15:43:08.687432    0.700804       0.512241  1.000
# 35 2024-11-09 15:46:38.022067   68.748367       0.493409  1.000
# 32 2024-11-09 15:41:24.361820    0.694137       0.491525  1.000
# 34 2024-11-09 15:44:53.269530    3.171730       0.491525  1.000
# 38 2024-11-09 15:26:31.659784    0.693776       0.491525  1.000
#
#                               band_to_frequency_range  batch_size  \
# 31  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 37  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 30  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 42  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 41  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 40  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...         128
# 43  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 44  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 36  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 39  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          32
# 33  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 35  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 32  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 34  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          64
# 38  {'alpha': [8, 14], 'beta': [14, 31], 'delta': ...          16
#
#     hid_channels        lr  max_epochs
# 31            64    0.0001         500
# 37            64    0.0010         500
# 30            64    0.0010         500
# 42            32    0.0010         500
# 41            16    0.0010         500
# 40            64    0.0010         500
# 43           128    0.0010         500
# 44           256    0.0010         500
# 36            64  100.0000         500
# 39            64    0.0010         500
# 33            64    0.1000         500
# 35            64   10.0000         500
# 32            64    0.0100         500
# 34            64    1.0000         500
# 38            64    0.0010         500
